# %%
import pandas as pd
from sqlalchemy import create_engine, text
from urllib.parse import quote_plus

# Charger le CSV
df = pd.read_csv('dette_propre_final.csv')

# Encoder le mot de passe pour éviter les conflits avec les caractères spéciaux
password = quote_plus('#password here')

# Créer une connexion sans spécifier la base de données pour pouvoir la créer
engine_temp = create_engine(f'mysql+mysqlconnector://root:{password}@localhost')

# Créer la base de données si elle n'existe pas
with engine_temp.connect() as conn:
    conn.execute(text("CREATE DATABASE IF NOT EXISTS Dette_Propre"))
    print("Base de données Dette_Propre créée ou existe déjà")

# se connecter à la base de données
engine = create_engine(f'mysql+mysqlconnector://root:{password}@localhost/Dette_Propre')

# Charger dans la table MySQL
df.to_sql(name='dataset', con=engine, if_exists='replace', index=False)

print("Données chargées avec succès dans MySQL !")
print(f"Nombre de lignes insérées : {len(df)}")
# Out:
# Base de données Dette_Propre créée ou existe déjà
# Données chargées avec succès dans MySQL !
# Nombre de lignes insérées : 610
# Données chargées avec succès dans MySQL !
# Nombre de lignes insérées : 610
